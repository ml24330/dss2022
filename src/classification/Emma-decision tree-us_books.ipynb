# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics 
from sklearn.model_selection import train_test_split
data=pd.read_csv("us_books.csv")

# %%
data
# Out:
#                id  listingIsTopRated  sellerFeedbackScore  \
# 0    155241304769                  0                  644
# 1    285024654485                  0                 3487
# 2    234758622811                  0                 2978
# 3    325412978422                  0                 1435
# 4    225230097747                  0                  400
# ..            ...                ...                  ...
# 519  165763992984                  0                 3013
# 520  155242918782                  0                    3
# 521  394303556010                  0                  619
# 522  334619268303                  0                 2029
# 523  134317477995                  0                 2082
#
#      sellerPositivePercent  sellerIsTopRated    price  endAtWeekend  \
# 0                    100.0                 0  38.6400             1
# 1                     97.6                 0   3.5700             0
# 2                    100.0                 0  34.4400             1
# 3                    100.0                 1  55.4400             1
# 4                    100.0                 1  37.8000             0
# ..                     ...               ...      ...           ...
# 519                  100.0                 1  30.2400             1
# 520                  100.0                 0  25.2000             1
# 521                  100.0                 1  42.0000             0
# 522                  100.0                 0  44.8000             0
# 523                  100.0                 1   6.7116             1
#
#      endAtEvening  length  isBroken  isUsed  isSet  freeShipping  isSold
# 0               0       7         0       0      1             0       1
# 1               1       7         0       1      0             0       1
# 2               0       7         0       0      1             0       1
# 3               0       7         0       1      1             0       1
# 4               1       7         0       1      1             0       1
# ..            ...     ...       ...     ...    ...           ...     ...
# 519             0       7         0       1      1             0       1
# 520             0       6         0       1      1             0       0
# 521             1       7         0       1      1             0       0
# 522             1       7         0       1      0             0       0
# 523             1       5         0       1      0             0       0
#
# [524 rows x 14 columns]

# %%
independentvariables = ['listingIsTopRated', 'sellerFeedbackScore', 'sellerPositivePercent', 'sellerIsTopRated','endAtWeekend','endAtEvening','length','isBroken','isUsed','isSet','freeShipping']
X = data[independentvariables] 
y = data.isSold
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
max_depth=list(range(1,10))
min_samples_split=list(range(1,10))
min_samples_leaf=list(range(1,10))
param_grid=dict(max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf)

# %%
model=DecisionTreeClassifier()
cv=RepeatedStratifiedKFold(n_splits=5,n_repeats=3,random_state=1)
search=GridSearchCV(model,param_grid,scoring="balanced_accuracy",cv=cv,n_jobs=-1)
search.fit(X_train,y_train)
# Out:
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ...
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [       nan 0.50968038 0.50968038 0.50968038 0.50968038 0.50968038
#  0.50968038 0.50968038 0.50968038        nan 0.50968038 0.50968038
#  0.50968038 0.50968038 0.50968038 0.50968038 0.50968038 0.50968038
#         nan 0.50968038 0.50968038 0.50968038 0.50968038 0.50968038
#  0.50968038 0.50968038 0.50968038        nan 0.50968038 0.50968038
#  0.50968038 0.50968038 0.50968038 0.50968038 0.50968038 0.50968038
#         nan 0.50968038 0.50968038 0.50968038 0.50968038 0.50968038
#  0.50968038 0.50968038 0.50968038        nan 0.50968038 0.50968038
#  0.50968038 0.50968038 0.50968038 0.50968038 0.50968038 0.50968038
#         nan 0.50968038 0.50968038 0.50968038 0.50968038 0.50968038
#  0.50968038 0.50968038 0.50968038        nan 0.50968038 0.50968038
#  0.50968038 0.50968038 0.50968038 0.50968038 0.50968038 0.50968038
#         nan 0.50968038 0.50968038 0.50968038 0.50968038 0.50968038
#  0.50968038 0.50968038 0.50968038        nan 0.51071403 0.51071403
#  0.51071403 0.5101932  0.5101932  0.5138969  0.51441774 0.5123344
#         nan 0.5117557  0.51227653 0.51227653 0.5117557  0.51227653
#  0.51493857 0.51441774 0.51285524        nan 0.51493857 0.51864227
#  0.51864227 0.51916311 0.51864227 0.51916311 0.51864227 0.51655894
#         nan 0.5154594  0.5154594  0.5154594  0.5154594  0.5154594
#  0.5154594  0.5154594  0.51441774        nan 0.51500445 0.51500445
#  0.51500445 0.51500445 0.51500445 0.51500445 0.51500445 0.51500445
#         nan 0.51130075 0.51130075 0.51130075 0.51130075 0.51130075
#  0.51130075 0.51130075 0.51130075        nan 0.51025908 0.51025908
#  0.51025908 0.51025908 0.51025908 0.51025908 0.51025908 0.51025908
#         nan 0.51025908 0.51025908 0.51025908 0.51025908 0.51025908
#  0.51025908 0.51025908 0.51025908        nan 0.51025908 0.51025908
#  0.51025908 0.51025908 0.51025908 0.51025908 0.51025908 0.51025908
#         nan 0.50390135 0.50760506 0.50760506 0.50812589 0.50390135
#  0.50760506 0.50760506 0.50552172        nan 0.50968839 0.50598469
#  0.50598469 0.50546385 0.50546385 0.50916756 0.50812589 0.50656339
#         nan 0.50916756 0.50916756 0.50968839 0.50916756 0.50916756
#  0.50916756 0.51235043 0.51078793        nan 0.51598024 0.51598024
#  0.51598024 0.5154594  0.51598024 0.5154594  0.5154594  0.51441774
#         nan 0.51448362 0.51448362 0.51448362 0.51448362 0.51448362
#  0.51448362 0.51448362 0.51448362        nan 0.51130075 0.51130075
#  0.51130075 0.51130075 0.51130075 0.51130075 0.51130075 0.51130075
#         nan 0.51344195 0.51344195 0.51344195 0.51344195 0.51344195
#  0.51344195 0.51344195 0.51344195        nan 0.51714566 0.51714566
#  0.51714566 0.51714566 0.51714566 0.51714566 0.51714566 0.51714566
#         nan 0.51714566 0.51714566 0.51714566 0.51714566 0.51714566
#  0.51714566 0.51714566 0.51714566        nan 0.52993501 0.52518964
#  0.52415598 0.52415598 0.52363515 0.52681802 0.52733885 0.52577635
#         nan 0.53047187 0.527289   0.527289   0.527289   0.5309927
#  0.53047187 0.5294302  0.52838853        nan 0.52040242 0.52040242
#  0.52410613 0.52040242 0.51988159 0.52358529 0.52676816 0.5257265
#         nan 0.52981927 0.52981927 0.52981927 0.52981927 0.52981927
#  0.5303401  0.52981927 0.52825677        nan 0.52195691 0.52195691
#  0.52195691 0.52195691 0.52195691 0.52195691 0.52195691 0.52195691
#         nan 0.51928686 0.51928686 0.51928686 0.51928686 0.51928686
#  0.51928686 0.51928686 0.51928686        nan 0.51876603 0.51876603
#  0.51876603 0.51876603 0.51876603 0.51876603 0.51876603 0.51876603
#         nan 0.51980769 0.51980769 0.51980769 0.51980769 0.51980769
#  0.51980769 0.51980769 0.51980769        nan 0.51662482 0.52032853
#  0.51662482 0.51662482 0.51662482 0.51662482 0.51662482 0.52032853
#         nan 0.51675659 0.51409455 0.51045673 0.5099359  0.51311877
#  0.5136396  0.5136396  0.51259793        nan 0.51409455 0.51091168
#  0.51461538 0.50987803 0.5130609  0.51624377 0.51624377 0.5152021
#         nan 0.51091969 0.50987803 0.51039886 0.51039886 0.51039886
#  0.51358173 0.5167646  0.5167646         nan 0.52937233 0.52514779
#  0.52566863 0.52989316 0.52937233 0.52566863 0.52514779 0.527289
#         nan 0.5235933  0.5235933  0.5235933  0.5235933  0.5161859
#  0.5161859  0.5235933  0.5161859         nan 0.51877404 0.51877404
#  0.51507033 0.51877404 0.51507033 0.51507033 0.51507033 0.51507033
#         nan 0.51825321 0.51825321 0.51825321 0.51825321 0.51825321
#  0.51825321 0.51825321 0.51825321        nan 0.51980769 0.51980769
#  0.51980769 0.51980769 0.51980769 0.51980769 0.51980769 0.51980769
#         nan 0.51662482 0.52032853 0.51662482 0.52032853 0.52032853
#  0.51662482 0.52032853 0.52032853        nan 0.53232194 0.52274929
#  0.5212687  0.52178152 0.52178152 0.52918091 0.5211948  0.523336
#         nan 0.52118679 0.51962429 0.51748308 0.51644943 0.51807781
#  0.52704772 0.52542735 0.52542735        nan 0.51853276 0.5227573
#  0.51801193 0.5190536  0.51801193 0.52379897 0.52379897 0.5227573
#         nan 0.52995103 0.5294302  0.5294302  0.53047187 0.52995103
#  0.53047187 0.5294302  0.52838853        nan 0.52789174 0.52789174
#  0.52418803 0.52418803 0.5199635  0.52418803 0.52789174 0.5273709
#         nan 0.52039441 0.51669071 0.51987358 0.52039441 0.51616987
#  0.51987358 0.51987358 0.51616987        nan 0.52195691 0.52195691
#  0.52195691 0.52195691 0.52195691 0.52195691 0.52195691 0.52195691
#         nan 0.51980769 0.51980769 0.51980769 0.51980769 0.51980769
#  0.51980769 0.51980769 0.51980769        nan 0.51662482 0.51662482
#  0.52032853 0.51662482 0.51662482 0.51662482 0.52032853 0.52032853
#         nan 0.50327902 0.50536236 0.50177439 0.50866097 0.50918981
#  0.51815171 0.5101656  0.50963675        nan 0.50539619 0.50858707
#  0.51229078 0.50969462 0.51977208 0.52288105 0.52021902 0.5217735
#         nan 0.52125267 0.51651531 0.51754897 0.5217735  0.51702813
#  0.52384882 0.52651086 0.52599003        nan 0.5315714  0.5315714
#  0.53105057 0.5315714  0.5315714  0.5315714  0.5315714  0.5300089
#         nan 0.52951211 0.52528757 0.52158387 0.52158387 0.5258084
#  0.5258084  0.52951211 0.5258084         nan 0.52253561 0.51935274
#  0.52253561 0.52253561 0.51883191 0.51935274 0.52305645 0.51883191
#         nan 0.52461895 0.52461895 0.52461895 0.52461895 0.52461895
#  0.52461895 0.52461895 0.52461895        nan 0.51980769 0.51980769
#  0.51980769 0.51980769 0.51980769 0.51980769 0.51980769 0.51980769
#         nan 0.52032853 0.51662482 0.51662482 0.51662482 0.52032853
#  0.52032853 0.52032853 0.52032853        nan 0.51610043 0.50971065
#  0.50822204 0.5092557  0.51614227 0.51503472 0.51127315 0.51125712
#         nan 0.50592504 0.50488337 0.5017005  0.50970264 0.51340634
#  0.52236823 0.51918536 0.520211          nan 0.50763533 0.51185986
#  0.50971866 0.51133903 0.51185986 0.51918536 0.5234099  0.52340189
#         nan 0.53002493 0.53002493 0.53054576 0.53054576 0.5310666
#  0.53054576 0.53054576 0.53001692        nan 0.52159188 0.52529558
#  0.52529558 0.52159188 0.52159188 0.52529558 0.52477475 0.52159188
#         nan 0.52253561 0.52253561 0.51883191 0.52305645 0.52305645
#  0.51935274 0.51883191 0.51883191        nan 0.52461895 0.52461895
#  0.52461895 0.52461895 0.52461895 0.52461895 0.52461895 0.52461895
#         nan 0.51980769 0.51980769 0.51980769 0.51980769 0.51980769
#  0.51980769 0.51980769 0.51980769        nan 0.52032853 0.52032853
#  0.52032853 0.51662482 0.52032853 0.51662482 0.51662482 0.52032853
#         nan 0.51725783 0.51779469 0.51096599 0.5003677  0.51362001
#  0.51355413 0.51511663 0.51348024        nan 0.52243412 0.5155235
#  0.51347222 0.52407051 0.52355769 0.53198273 0.53302439 0.53242967
#         nan 0.51400107 0.51667112 0.51562945 0.51244658 0.51614227
#  0.52503828 0.52822115 0.52977564        nan 0.52898326 0.52846243
#  0.5295041  0.52846243 0.52898326 0.52898326 0.52846243 0.52845442
#         nan 0.51950855 0.52373308 0.52002938 0.52321225 0.52002938
#  0.52002938 0.52743679 0.52743679        nan 0.51831108 0.51831108
#  0.51831108 0.51779024 0.52149395 0.52201478 0.52201478 0.51831108
#         nan 0.52461895 0.52461895 0.52461895 0.52461895 0.52461895
#  0.52461895 0.52461895 0.52461895        nan 0.51980769 0.51980769
#  0.51980769 0.51980769 0.51980769 0.51980769 0.51980769 0.51980769
#         nan 0.51662482 0.52032853 0.51662482 0.52032853 0.51662482
#  0.51662482 0.52032853 0.51662482]
#   warnings.warn(
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=5, random_state=1),
#              estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [1, 2, 3, 4, 5, 6, 7, 8, 9],
#                          'min_samples_leaf': [1, 2, 3, 4, 5, 6, 7, 8, 9],
#                          'min_samples_split': [1, 2, 3, 4, 5, 6, 7, 8, 9]},
#              scoring='balanced_accuracy')

# %%
print("Best parameter (CV score=%0.3f):"% search.best_score_)
print(search.best_params_)
# Out:
# Best parameter (CV score=0.533):
# {'max_depth': 9, 'min_samples_leaf': 2, 'min_samples_split': 8}

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
clf = DecisionTreeClassifier(max_depth=8, min_samples_leaf=3, min_samples_split=4)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

acc_one = accuracy_score(y_test, y_pred)

cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)

disp.plot()

# %%
features = X.columns.tolist()

# %%
clf = DecisionTreeClassifier(max_depth=9, min_samples_leaf=2, min_samples_split=4)
clf.fit(X_train, y_train)
importances_sk=clf.feature_importances_



feature_importance_sk = {}
for i, feature in enumerate(features):
    feature_importance_sk[feature] = round(importances_sk[i], 3)

print(f"Feature importance by sklearn: {feature_importance_sk}")
# Out:
# Feature importance by sklearn: {'listingIsTopRated': 0.0, 'sellerFeedbackScore': 0.58, 'sellerPositivePercent': 0.101, 'sellerIsTopRated': 0.085, 'endAtWeekend': 0.03, 'endAtEvening': 0.057, 'length': 0.071, 'isBroken': 0.0, 'isUsed': 0.024, 'isSet': 0.039, 'freeShipping': 0.013}
