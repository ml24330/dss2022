# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics 
from sklearn.model_selection import train_test_split
data=pd.read_csv("uk_books.csv")

# %%
data
# Out:
#                 id  listingIsTopRated  sellerFeedbackScore  \
# 0     155231441853                  0                    4
# 1     374332149207                  0                  427
# 2     204134034335                  0                 8880
# 3     374332118703                  0                  427
# 4     225230024645                  1                 1574
# ...            ...                ...                  ...
# 1320  195456484615                  0                  794
# 1321  155242914406                  0                 2141
# 1322  185645964237                  0                 1043
# 1323  374341024196                  0                   66
# 1324  403979584445                  0                   16
#
#       sellerPositivePercent  sellerIsTopRated  price  endAtWeekend  \
# 0                     100.0                 0  80.00             1
# 1                     100.0                 0   8.50             1
# 2                     100.0                 0  10.02             1
# 3                     100.0                 0  46.00             1
# 4                     100.0                 1  12.50             1
# ...                     ...               ...    ...           ...
# 1320                  100.0                 0  40.00             1
# 1321                  100.0                 0  25.00             1
# 1322                  100.0                 0  12.99             1
# 1323                  100.0                 0  65.00             1
# 1324                  100.0                 0   8.50             1
#
#       endAtEvening  length  isBroken  isUsed  isSet  freeShipping  isSold
# 0                1       6         0       0      0             0       1
# 1                1       5         0       1      1             0       1
# 2                1      10         0       1      0             0       1
# 3                1       5         0       1      0             0       1
# 4                1       7         0       1      1             0       1
# ...            ...     ...       ...     ...    ...           ...     ...
# 1320             1       7         0       0      0             0       0
# 1321             1       7         0       1      0             0       0
# 1322             1       7         0       0      0             0       0
# 1323             1       7         0       1      0             0       0
# 1324             0       6         0       0      0             0       0
#
# [1325 rows x 14 columns]

# %%
independentvariables = ['listingIsTopRated', 'sellerFeedbackScore', 'sellerPositivePercent', 'sellerIsTopRated','endAtWeekend','endAtEvening','length','isBroken','isUsed','isSet','freeShipping']
X = data[independentvariables] 
y = data.isSold
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
max_depth=list(range(1,10))
min_samples_split=list(range(1,10))
min_samples_leaf=list(range(1,10))
param_grid=dict(max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf)

# %%
model=DecisionTreeClassifier()
cv=RepeatedStratifiedKFold(n_splits=5,n_repeats=3,random_state=1)
search=GridSearchCV(model,param_grid,scoring="balanced_accuracy",cv=cv,n_jobs=-1)
search.fit(X_train,y_train)
# Out:
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ...
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [       nan 0.51759222 0.51759222 0.51759222 0.51759222 0.51759222
#  0.51759222 0.51759222 0.51759222        nan 0.51759222 0.51759222
#  0.51759222 0.51759222 0.51759222 0.51759222 0.51759222 0.51759222
#         nan 0.51759222 0.51759222 0.51759222 0.51759222 0.51759222
#  0.51759222 0.51759222 0.51759222        nan 0.51246402 0.51246402
#  0.51246402 0.51246402 0.51246402 0.51246402 0.51246402 0.51246402
#         nan 0.50605376 0.50605376 0.50605376 0.50605376 0.50605376
#  0.50605376 0.50605376 0.50605376        nan 0.5047959  0.5047959
#  0.5047959  0.5047959  0.5047959  0.5047959  0.5047959  0.5047959
#         nan 0.5047959  0.5047959  0.5047959  0.5047959  0.5047959
#  0.5047959  0.5047959  0.5047959         nan 0.5047959  0.5047959
#  0.5047959  0.5047959  0.5047959  0.5047959  0.5047959  0.5047959
#         nan 0.5047959  0.5047959  0.5047959  0.5047959  0.5047959
#  0.5047959  0.5047959  0.5047959         nan 0.51672684 0.51672684
#  0.51672684 0.51672684 0.51672684 0.51672684 0.51672684 0.51672684
#         nan 0.51672684 0.51672684 0.51672684 0.51672684 0.51672684
#  0.51672684 0.51672684 0.51672684        nan 0.51797684 0.51797684
#  0.51797684 0.51797684 0.51797684 0.51797684 0.51797684 0.51797684
#         nan 0.51159863 0.51159863 0.51159863 0.51159863 0.51159863
#  0.51159863 0.51159863 0.51159863        nan 0.51225437 0.51225437
#  0.51225437 0.51225437 0.51225437 0.51225437 0.51225437 0.51225437
#         nan 0.51270178 0.51377419 0.51270178 0.51270178 0.51270178
#  0.51356455 0.51377419 0.51270178        nan 0.51013244 0.51013244
#  0.51013244 0.50992279 0.50992279 0.51013244 0.50992279 0.51013244
#         nan 0.51186059 0.51227987 0.51227987 0.51186059 0.51186059
#  0.51227987 0.51186059 0.51186059        nan 0.51231062 0.51189133
#  0.51231062 0.51231062 0.51231062 0.51189133 0.51189133 0.51189133
#         nan 0.51589219 0.51589219 0.51589219 0.51589219 0.51589219
#  0.51589219 0.51589219 0.51589219        nan 0.51589219 0.51589219
#  0.51589219 0.51589219 0.51589219 0.51589219 0.51589219 0.51589219
#         nan 0.51949927 0.51949927 0.51949927 0.51949927 0.51949927
#  0.51949927 0.51949927 0.51949927        nan 0.51031658 0.51031658
#  0.51031658 0.51031658 0.51031658 0.51031658 0.51031658 0.51031658
#         nan 0.5118364  0.5118364  0.5118364  0.51055435 0.51055435
#  0.51055435 0.51055435 0.51055435        nan 0.51225437 0.51055304
#  0.51246402 0.51225437 0.51246402 0.51204473 0.51055304 0.51118197
#         nan 0.51054779 0.51075744 0.51075744 0.51075744 0.51054779
#  0.51075744 0.51075744 0.51075744        nan 0.51227987 0.51186059
#  0.51227987 0.51186059 0.51186059 0.51227987 0.51186059 0.51227987
#         nan 0.51231062 0.51231062 0.51189133 0.51231062 0.51189133
#  0.51189133 0.51189133 0.51189133        nan 0.51277828 0.51277828
#  0.51277828 0.51277828 0.51277828 0.51277828 0.51277828 0.51256995
#         nan 0.51361424 0.51361424 0.51361424 0.51361424 0.51361424
#  0.51361424 0.51361424 0.5134059         nan 0.51701298 0.51701298
#  0.51722263 0.51701298 0.51701298 0.51701298 0.51701298 0.5180867
#         nan 0.51147204 0.51147204 0.51147204 0.51147204 0.51147204
#  0.51147204 0.51147204 0.51147204        nan 0.50869436 0.50848734
#  0.50890401 0.50997642 0.50890401 0.5082777  0.51018606 0.50869436
#         nan 0.51039701 0.50911496 0.51060666 0.51060666 0.50997773
#  0.50911496 0.51039701 0.51018737        nan 0.51081106 0.51081106
#  0.51060142 0.51081106 0.51060142 0.51060142 0.51060142 0.51081106
#         nan 0.51000454 0.50958525 0.50958525 0.51000454 0.51000454
#  0.51000454 0.51000454 0.51000454        nan 0.51003528 0.51045456
#  0.51045456 0.51045456 0.51003528 0.51003528 0.51045456 0.51003528
#         nan 0.51945442 0.5194518  0.51879737 0.51837808 0.51966145
#  0.5194518  0.51837808 0.51816975        nan 0.52028907 0.52028907
#  0.52028907 0.52007942 0.52007942 0.52007942 0.51966276 0.51945442
#         nan 0.52374012 0.52374012 0.52502217 0.52502217 0.52502217
#  0.52502217 0.52394977 0.52630554        nan 0.5188909  0.51951984
#  0.51847162 0.51760885 0.51910055 0.51868126 0.51826197 0.51930888
#         nan 0.51527858 0.51805233 0.51677028 0.51784269 0.51677028
#  0.51656064 0.51548823 0.51742602        nan 0.51352494 0.512896
#  0.5118236  0.512896   0.51161395 0.51310565 0.5118236  0.51224288
#         nan 0.51204826 0.51204826 0.51204826 0.51183861 0.51163028
#  0.51183993 0.51183861 0.51183993        nan 0.50843856 0.50843856
#  0.50843856 0.50843856 0.50843856 0.50801927 0.50801927 0.50801927
#         nan 0.51124305 0.51082376 0.51124305 0.51124305 0.51082376
#  0.51124305 0.51124305 0.51082376        nan 0.52472716 0.5249368
#  0.52451752 0.52538028 0.52538028 0.52472585 0.52538028 0.52517195
#         nan 0.52192267 0.52341175 0.52448678 0.52341175 0.52278675
#  0.52171303 0.5208797  0.52195341        nan 0.52600266 0.52579433
#  0.52794045 0.5287751  0.52749305 0.52600266 0.52538159 0.53030015
#         nan 0.52470166 0.5238644  0.52812853 0.52470166 0.52512095
#  0.52363056 0.52258104 0.5259824         nan 0.5253829  0.5253829
#  0.52365082 0.52728995 0.52728995 0.52451752 0.5234438  0.52728995
#         nan 0.51953747 0.5216836  0.52230991 0.51953747 0.52081953
#  0.52230991 0.52102917 0.5206125         nan 0.52169731 0.52104419
#  0.52232362 0.52020823 0.52190564 0.52169731 0.52125252 0.51955249
#         nan 0.51660115 0.51702044 0.51702044 0.51702044 0.51702044
#  0.51660115 0.51702044 0.51702044        nan 0.51961659 0.51768142
#  0.51768142 0.51726214 0.51768142 0.51726214 0.51726214 0.51961659
#         nan 0.53577205 0.53619003 0.53619003 0.53514443 0.5334444
#  0.53237331 0.53216628 0.5296048         nan 0.52974772 0.5261099
#  0.52867269 0.52804507 0.53102715 0.52718362 0.52506823 0.52656124
#         nan 0.53147587 0.53338554 0.53210349 0.53466628 0.53723039
#  0.53296888 0.5323465  0.53532989        nan 0.53488772 0.53619265
#  0.53470227 0.5353057  0.53407202 0.53211397 0.53407333 0.53682158
#         nan 0.5349106  0.53192852 0.52957406 0.53255614 0.53470358
#  0.53172019 0.52895037 0.53002278        nan 0.52711105 0.52880846
#  0.52922775 0.525829   0.52645531 0.52839179 0.5269001  0.52818215
#         nan 0.52733047 0.52584009 0.52649452 0.52607785 0.52628618
#  0.52777657 0.52563044 0.52628487        nan 0.52178953 0.52137024
#  0.52178953 0.52137024 0.52137024 0.52137024 0.52137024 0.52137024
#         nan 0.52074917 0.52032989 0.52268959 0.52119789 0.52119789
#  0.52268959 0.52032989 0.52182158        nan 0.53968947 0.54243509
#  0.54222938 0.54309083 0.5418114  0.53775953 0.53608763 0.53457174
#         nan 0.54115173 0.53623186 0.53751391 0.53879727 0.53942096
#  0.53450371 0.53259928 0.53110889        nan 0.54219733 0.54240959
#  0.5419903  0.54625312 0.54431795 0.54306402 0.54286093 0.5441456
#         nan 0.54134505 0.5400388  0.53943799 0.54006692 0.5400388
#  0.53857523 0.54090157 0.54152919        nan 0.53494003 0.54006955
#  0.53795547 0.53708878 0.53687913 0.54093624 0.54027919 0.53580672
#         nan 0.53328223 0.53307259 0.53566874 0.53480205 0.53393928
#  0.5345924  0.53438276 0.53352           nan 0.53224772 0.53290608
#  0.53570271 0.53377147 0.53290477 0.53615012 0.53483601 0.53549438
#         nan 0.52262286 0.52005614 0.52047543 0.52262286 0.52005614
#  0.52005614 0.52005614 0.52047543        nan 0.52352292 0.52161194
#  0.52417997 0.52203122 0.52161194 0.52417997 0.52203122 0.52310363
#         nan 0.5454338  0.54475125 0.54538149 0.54454292 0.54579554
#  0.54111474 0.5377428  0.53771861        nan 0.54422603 0.54252338
#  0.54273172 0.5414791  0.54401246 0.53417533 0.53355296 0.53206126
#         nan 0.54231767 0.54529844 0.54103562 0.5399619  0.53933821
#  0.54380937 0.54339925 0.5395531         nan 0.53759373 0.54102322
#  0.53971436 0.54036748 0.53995081 0.53971436 0.54057975 0.54015915
#         nan 0.53613671 0.53676302 0.54060918 0.53783543 0.53849117
#  0.53697005 0.54018989 0.5382521         nan 0.53169993 0.53256531
#  0.53190957 0.53340127 0.53190957 0.53274552 0.53277496 0.53190957
#         nan 0.53064516 0.53365012 0.53278604 0.53082275 0.52998811
#  0.53299307 0.53236807 0.52998942        nan 0.52012286 0.51970358
#  0.51904652 0.52161325 0.52161325 0.51970358 0.51970358 0.51970358
#         nan 0.52316905 0.52466074 0.52424145 0.52424145 0.52316905
#  0.52466074 0.52382479 0.52424407]
#   warnings.warn(
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=5, random_state=1),
#              estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [1, 2, 3, 4, 5, 6, 7, 8, 9],
#                          'min_samples_leaf': [1, 2, 3, 4, 5, 6, 7, 8, 9],
#                          'min_samples_split': [1, 2, 3, 4, 5, 6, 7, 8, 9]},
#              scoring='balanced_accuracy')

# %%
print("Best parameter (CV score=%0.3f):"% search.best_score_)
print(search.best_params_)
# Out:
# Best parameter (CV score=0.546):
# {'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
clf = DecisionTreeClassifier(max_depth=9, min_samples_leaf=2, min_samples_split=9)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

acc_one = accuracy_score(y_test, y_pred)

cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)

disp.plot()

# %%
features = X.columns.tolist()

# %%
clf = DecisionTreeClassifier(max_depth=9, min_samples_leaf=2, min_samples_split=4)
clf.fit(X_train, y_train)
importances_sk=clf.feature_importances_


feature_importance_sk = {}
for i, feature in enumerate(features):
    feature_importance_sk[feature] = round(importances_sk[i], 3)

print(f"Feature importance by sklearn: {feature_importance_sk}")
# Out:
# Feature importance by sklearn: {'listingIsTopRated': 0.0, 'sellerFeedbackScore': 0.556, 'sellerPositivePercent': 0.121, 'sellerIsTopRated': 0.0, 'endAtWeekend': 0.051, 'endAtEvening': 0.066, 'length': 0.088, 'isBroken': 0.0, 'isUsed': 0.076, 'isSet': 0.042, 'freeShipping': 0.001}
