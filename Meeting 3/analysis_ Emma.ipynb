# %%
import pandas as pd
from db_utils import Query, QueryAll

data = QueryAll()
cols = ["id", "title", "globalId", "categoryId", "categoryName", "url", "location", "shippingType", "shippingLocations",
                "shippingTime", "startTime", "endTime", "returnsAccepted", "conditionId", "listingIsTopRated", 
                "sellerFeedbackScore", "sellerPositivePercent", "sellerName", "sellerIsTopRated", "price", "currency", "bids"]

# %%
df = pd.DataFrame(data, columns=cols)

# %%
df
# Out:
#                 id                                              title  \
# 0     134299363330  Canon EOS 6D Mark II 26,2 MP DSLR Camera, Batt...
# 1     265951804753  GoPro Hero5 Black 4k Action Camera with Floati...
# 2     134296030570                             sony a6000 camera body
# 3     325395882420  Sony Alpha A6400 24.2MP Digital Camera - Black...
# 4     134306375330  (2 Count) Ring Stick Up Cam Battery HD Securit...
# ...            ...                                                ...
# 9894  374321074110  Microsoft Surface Pro 4 Tablet 12.3" M3-6Y30 ....
# 9895  155231679243  Brand New Box Unopened - Sony FX6 Full-Frame C...
# 9896  185630674304  Apple iPhone 13 Pro Max - 128GB - Sierra Blue ...
# 9897  185638379717  Apple iPhone XR Black 64GB A1984 Unlocked - Ve...
# 9898  165748956995                  sense-u video baby monitor camera
#
#      globalId  categoryId               categoryName  \
# 0     EBAY-US       31388            Digital Cameras
# 1     EBAY-US       31388            Digital Cameras
# 2     EBAY-US       31388            Digital Cameras
# 3     EBAY-US       31388            Digital Cameras
# 4     EBAY-US       48638           Security Cameras
# ...       ...         ...                        ...
# 9894  EBAY-US      171485    Tablets & eBook Readers
# 9895  EBAY-US       11724                 Camcorders
# 9896  EBAY-US        9355  Cell Phones & Smartphones
# 9897  EBAY-US        9355  Cell Phones & Smartphones
# 9898  EBAY-US       20435              Baby Monitors
#
#                                                     url              location  \
# 0     https://www.ebay.com/itm/Canon-EOS-6D-Mark-II-...        Sebring,FL,USA
# 1     https://www.ebay.com/itm/GoPro-Hero5-Black-4k-...     West Fargo,ND,USA
# 2     https://www.ebay.com/itm/sony-a6000-camera-bod...  Coeur d'Alene,ID,USA
# 3     https://www.ebay.com/itm/Sony-Alpha-A6400-24-2...          Tampa,FL,USA
# 4     https://www.ebay.com/itm/2-Count-Ring-Stick-Up...     Louisville,KY,USA
# ...                                                 ...                   ...
# 9894  https://www.ebay.com/itm/Microsoft-Surface-Pro...         Dallas,TX,USA
# 9895  https://www.ebay.com/itm/Brand-New-Box-Unopene...       Lakewood,CA,USA
# 9896  https://www.ebay.com/itm/Apple-iPhone-13-Pro-M...  Mountain Home,AR,USA
# 9897  https://www.ebay.com/itm/Apple-iPhone-XR-Black...      Ashtabula,OH,USA
# 9898  https://www.ebay.com/itm/sense-u-video-baby-mo...      Charlotte,NC,USA
#
#      shippingType shippingLocations  shippingTime  ... returnsAccepted  \
# 0      FreePickup         Worldwide             0  ...               0
# 1            Flat         Worldwide             3  ...               0
# 2            Free         Worldwide             3  ...               0
# 3            Flat         Worldwide             2  ...               0
# 4            Free         Worldwide             0  ...               0
# ...           ...               ...           ...  ...             ...
# 9894         Free         Worldwide             1  ...               1
# 9895         Flat         Worldwide             3  ...               0
# 9896   Calculated         Worldwide             1  ...               1
# 9897   Calculated         Worldwide             1  ...               0
# 9898         Flat         Worldwide             3  ...               0
#
#      conditionId  listingIsTopRated  sellerFeedbackScore  \
# 0           3000                  0                   52
# 1           3000                  0                  929
# 2           3000                  0                  736
# 3           3000                  0                 1028
# 4           1000                  0                  268
# ...          ...                ...                  ...
# 9894        3000                  0                38272
# 9895        1000                  0                 2198
# 9896        3000                  0                 3767
# 9897        3000                  0                   88
# 9898        3000                  0                13530
#
#       sellerPositivePercent        sellerName  sellerIsTopRated    price  \
# 0                     100.0       revettflseb                 0   787.00
# 1                      99.7      brody.dreger                 1    33.00
# 2                     100.0         brasstang                 0   240.00
# 3                     100.0           jrsnick                 1   717.00
# 4                      96.6   roshicardisland                 0   131.00
# ...                     ...               ...               ...      ...
# 9894                   99.9    immortalorigin                 1    72.00
# 9895                   95.5  paperisdelicious                 0  7199.99
# 9896                  100.0        cellerific                 0   593.00
# 9897                  100.0        droosevelt                 0   119.00
# 9898                   99.9   thegridgoodwill                 0    11.99
#
#       currency  bids
# 0           -1    -1
# 1           -1    -1
# 2           -1    -1
# 3           -1    -1
# 4           -1    -1
# ...        ...   ...
# 9894        -1    -1
# 9895        -1    -1
# 9896        -1    -1
# 9897        -1    -1
# 9898        -1    -1
#
# [9899 rows x 22 columns]

# %%
y=df.iloc[:,-3]

# %%
x=df.loc[:,["listingIsTopRated","shippingTime","sellerPositivePercent","returnsAccepted","sellerFeedbackScore","sellerIsTopRated","currency","bids"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size= 0.3,random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor=RandomForestRegressor(n_estimators=10,random_state=0)

# %%
regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
y_predict=regressor.predict(x_test)

# %%
y_predict
# Out:
# array([175.387     ,  10.64051429,  92.81183239, ...,  22.82110037,
#         35.9028381 , 152.299     ])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, y_predict)
# Out:
# 296942.14249978604

# %%
y.var()
# Out:
# 257622.77721840984
