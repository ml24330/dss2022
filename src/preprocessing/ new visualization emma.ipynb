# %%
import pandas as pd
from db_utils import QueryAll

# Wall clock data
data_clocks = QueryAll("clock_uk")

# Harry Potter book data
data_books = QueryAll("book_uk")

cols = ["id", "title", "globalId", "categoryId", "categoryName", "url", "location", "shippingType", "shippingLocations",
                "shippingTime", "startTime", "endTime", "returnsAccepted", "conditionId", "listingIsTopRated", 
                "sellerFeedbackScore", "sellerPositivePercent", "sellerName", "sellerIsTopRated", "price", "currency", "bids"]

clocks = pd.DataFrame(data_clocks, columns=cols)
books = pd.DataFrame(data_books, columns=cols)

df_clocks = clocks[(clocks.bids != -1) & (clocks.bids != -2)].reset_index()
df_books = books[(books.bids != -1) & (books.bids != -2)].reset_index()

# %%
df_clocks
# Out:
#      index            id                                              title  \
# 0        1  225229693627                                        retro clock
# 1        3  265963174354  large oval wall clock  Silver And White Face 4...
# 2        4  325404594797  Lisa Parker Silver Effect Tree Of Life Wall Cl...
# 3        5  204136797199                   9" WOODEN WALL CLOCK BLACK HANDS
# 4        6  185638233876  Surreal Melting Distorted Clock Creative Salva...
# ..     ...           ...                                                ...
# 488   2714  165752410069  Newgate “Echo Number One” Wall Clock, Dia 53cm...
# 489   2724  125589131588  Emma Bridgewater pink hearts clock (needs new ...
# 490   2729  275523415574  Premier 240 LED Snowing Icicles Multi-Action X...
# 491   2993  394312524769              Vintage Retro 1970 Metamic Wall Clock
# 492   3024  265964362490                      Wedgwood  Foxwood Tales Clock
#
#     globalId  categoryId   categoryName  \
# 0    EBAY-GB       20561    Wall Clocks
# 1    EBAY-GB       20561    Wall Clocks
# 2    EBAY-GB       20561    Wall Clocks
# 3    EBAY-GB       20561    Wall Clocks
# 4    EBAY-GB       20561    Wall Clocks
# ..       ...         ...            ...
# 488  EBAY-GB       20561    Wall Clocks
# 489  EBAY-GB      262393         Clocks
# 490  EBAY-GB       38229  String Lights
# 491  EBAY-GB      261608    Wall Clocks
# 492  EBAY-GB      261608    Wall Clocks
#
#                                                    url  \
# 0    https://www.ebay.co.uk/itm/retro-clock-/225229...
# 1    https://www.ebay.co.uk/itm/large-oval-wall-clo...
# 2    https://www.ebay.co.uk/itm/Lisa-Parker-Silver-...
# 3    https://www.ebay.co.uk/itm/9-WOODEN-WALL-CLOCK...
# 4    https://www.ebay.co.uk/itm/Surreal-Melting-Dis...
# ..                                                 ...
# 488  https://www.ebay.co.uk/itm/Newgate-Echo-Number...
# 489  https://www.ebay.co.uk/itm/Emma-Bridgewater-pi...
# 490  https://www.ebay.co.uk/itm/Premier-240-LED-Sno...
# 491  https://www.ebay.co.uk/itm/Vintage-Retro-1970-...
# 492  https://www.ebay.co.uk/itm/Wedgwood-Foxwood-Ta...
#
#                        location shippingType shippingLocations  ...  \
# 0          Lewes,United Kingdom         Flat         Worldwide  ...
# 1        Staines,United Kingdom         Flat         Worldwide  ...
# 2     Sunderland,United Kingdom         Flat         Worldwide  ...
# 3          Tenby,United Kingdom         Flat         Worldwide  ...
# 4      Harleston,United Kingdom         Flat         Worldwide  ...
# ..                          ...          ...               ...  ...
# 488        Derby,United Kingdom   FreePickup         Worldwide  ...
# 489  Hope Valley,United Kingdom         Free         Worldwide  ...
# 490     Bradford,United Kingdom         Flat         Worldwide  ...
# 491     Alfreton,United Kingdom         Flat         Worldwide  ...
# 492     Kidwelly,United Kingdom         Free         Worldwide  ...
#
#      returnsAccepted conditionId listingIsTopRated  sellerFeedbackScore  \
# 0                 -1        3000                 0                  255
# 1                 -1        3000                 0                 1466
# 2                 -1        1000                 0                  920
# 3                 -1        3000                 0                 2993
# 4                 -1        3000                 0                  232
# ..               ...         ...               ...                  ...
# 488               -1        1000                 0                 1353
# 489               -1        7000                 0                  479
# 490               -1        1000                 0                  740
# 491               -1        3000                 0                 1775
# 492               -1        1000                 0                  314
#
#      sellerPositivePercent      sellerName  sellerIsTopRated   price currency  \
# 0                    100.0   uphillonfixed                 0   £5.00       -1
# 1                    100.0     lizzie-drip                 0  £10.00       -1
# 2                    100.0       paulasf17                 0  £13.99       -1
# 3                    100.0        marpow61                 0   £4.98       -1
# 4                    100.0        khun6253                 0   £3.20       -1
# ..                     ...             ...               ...     ...      ...
# 488                  100.0    sharont01543                 0  £45.00       -1
# 489                  100.0    jennyblue222                 0  £23.00       -1
# 490                  100.0      2013star14                 0  £25.99       -1
# 491                  100.0      bronski000                 0  £20.99       -1
# 492                  100.0  techie-richard                 0  £35.00       -1
#
#      bids
# 0       0
# 1       1
# 2       0
# 3       0
# 4       5
# ..    ...
# 488     0
# 489     4
# 490     0
# 491     0
# 492     0
#
# [493 rows x 23 columns]

# %%
# !pip install wordcloud
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS 
# Start with one review:
text = str(df_clocks["title"])
stop_words = STOPWORDS.update(["clock", "wall"])
# Create and generate a word cloud image:
wordcloud = WordCloud(stopwords = stop_words).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# Requirement already satisfied: wordcloud in /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages (1.8.2.2)
# Requirement already satisfied: matplotlib in /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: numpy>=1.6.1 in /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages (from wordcloud) (1.20.3)
# Requirement already satisfied: pillow in /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: six in /Users/xiamglimli/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Start with one review:
text = str(df_books["title"])
stop_words = ["Harry Potter","BOOK"]
print(stop_words)
# Out:
# ['Harry Potter', 'BOOK']

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Start with one review:
text = str(df_books["title"])

stop_words = ["Harry Potter","books"]

# Create and generate a word cloud image:
wordcloud = WordCloud(stopwords = stop_words).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#clocks shipping type visualization
flat = 0
Freeshipping = 0
freepickup = 0
for x in df_clocks['shippingType']:
    if x == "Flat":
        flat += 1
    elif x == "FreePickup":
        freepickup += 1
    else: 
        Freeshipping += 1

# %%
import matplotlib.pyplot as plt
frequency = [422, 23, 48]
shippingtype = ["Flat", "Freeshippingtype", "freepickup"]
plt.bar(shippingtype,frequency)
plt.xlabel("clocks shippingtype")
plt.ylabel("clocks shippingtype Freq")
plt.title("clocks shippingtype bar chart")

plt.show()

# %%
#books shipping type visualization
flat = 0
Freeshipping = 0
freepickup = 0
for x in df_books['shippingType']:
    if x == "Flat":
        flat += 1
    elif x == "FreePickup":
        freepickup += 1
    else: 
        Freeshipping += 1

# %%
import matplotlib.pyplot as plt
frequency = [190, 5, 1]
shippingtype = ["Flat", "Freeshippingtype", "freepickup"]
plt.bar(shippingtype,frequency)
plt.xlabel("Book shippingtype")
plt.ylabel("Book shippingtype Freq")
plt.title("books shippingtype bar chart")

plt.show()

# %%
#clock returnsAccepted visualization
clock_label = df_clocks['returnsAccepted'].unique()
clock_size = df_clocks['returnsAccepted'].value_counts().tolist()

plt.title('clock returnsAccepted distribution')

plt.pie(clock_size, labels = clock_label)
plt.show()

# %%
#books returnsAccepted visualization
books_label = df_books['returnsAccepted'].unique()
books_size = df_books['returnsAccepted'].value_counts().tolist()

plt.title('book returnsAccepted distribution')

plt.pie(books_size, labels = books_label)
plt.show()
