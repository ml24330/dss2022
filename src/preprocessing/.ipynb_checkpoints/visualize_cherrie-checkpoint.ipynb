# %%
import matplotlib.pyplot as plt
from db_utils import QueryAll
import pandas as pd
import re

# Wall clock data
data_clocks = QueryAll("clock_uk")

# Harry Potter book data
data_books = QueryAll("book_uk")

cols = ["id", "title", "globalId", "categoryId", "categoryName", "url", "location", "shippingType", "shippingLocations",
                "shippingTime", "startTime", "endTime", "returnsAccepted", "conditionId", "listingIsTopRated", 
                "sellerFeedbackScore", "sellerPositivePercent", "sellerName", "sellerIsTopRated", "price", "currency", "bids"]

clocks = pd.DataFrame(data_clocks, columns=cols)
books = pd.DataFrame(data_books, columns=cols)

df_clocks = clocks[(clocks.bids != -1) & (clocks.bids != -2)].reset_index()
df_books = books[(books.bids != -1) & (books.bids != -2)].reset_index()

# %%
df_clocks
# Out:
#       index            id                                              title  \
# 0         0  204143979657       Quartz Singing Bird Clock Green New With Box
# 2         2  325413562414  Round Wall Clock Bedroom Kitchen Clocks Quartz...
# 3         3  265963174354  large oval wall clock  Silver And White Face 4...
# 6         6  185638233876  Surreal Melting Distorted Clock Creative Salva...
# 7         7  204142979084                              Jones Butterfly Clock
# ...     ...           ...                                                ...
# 2807   3055  295281986621  Vintage brass ships wall clock London quartz m...
# 2808   3056  165764075512  Retro metal kitchen wall clock with built-in t...
# 2847   3105  125599684567               brass clock pendulum and Winding key
# 2871   3138  334616844608  Orange Metamec Orange Mains Wall Clock Faulty B88
# 2886   3155  255814096426  30Fc) Alte Comtoise Wanduhr Uhrwerk mit Liebes...
#
#      globalId  categoryId               categoryName  \
# 0     EBAY-GB       20561                Wall Clocks
# 2     EBAY-GB       20561                Wall Clocks
# 3     EBAY-GB       20561                Wall Clocks
# 6     EBAY-GB       20561                Wall Clocks
# 7     EBAY-GB       20561                Wall Clocks
# ...       ...         ...                        ...
# 2807  EBAY-GB       66638            Marine/Maritime
# 2808  EBAY-GB       98852             Kitchen Timers
# 2847  EBAY-GB      261609  Replacement Parts & Tools
# 2871  EBAY-GB       20561                Wall Clocks
# 2886  EBAY-DE      261608                  Wanduhren
#
#                                                     url  \
# 0     https://www.ebay.co.uk/itm/Quartz-Singing-Bird...
# 2     https://www.ebay.co.uk/itm/Round-Wall-Clock-Be...
# 3     https://www.ebay.co.uk/itm/large-oval-wall-clo...
# 6     https://www.ebay.co.uk/itm/Surreal-Melting-Dis...
# 7     https://www.ebay.co.uk/itm/Jones-Butterfly-Clo...
# ...                                                 ...
# 2807  https://www.ebay.co.uk/itm/Vintage-brass-ships...
# 2808  https://www.ebay.co.uk/itm/Retro-metal-kitchen...
# 2847  https://www.ebay.co.uk/itm/brass-clock-pendulu...
# 2871  https://www.ebay.co.uk/itm/Orange-Metamec-Oran...
# 2886  https://www.ebay.co.uk/itm/30Fc-Alte-Comtoise-...
#
#                              location shippingType shippingLocations  ...  \
# 0     Bury St. Edmunds,United Kingdom         Flat         Worldwide  ...
# 2          King's Lynn,United Kingdom         Flat         Worldwide  ...
# 3              Staines,United Kingdom         Flat         Worldwide  ...
# 6            Harleston,United Kingdom         Flat         Worldwide  ...
# 7                Derby,United Kingdom         Flat         Worldwide  ...
# ...                               ...          ...               ...  ...
# 2807         Blackpool,United Kingdom         Flat         Worldwide  ...
# 2808            Malton,United Kingdom         Flat         Worldwide  ...
# 2847         Knutsford,United Kingdom         Flat         Worldwide  ...
# 2871         Kirkcaldy,United Kingdom         Free         Worldwide  ...
# 2886                          Germany         Flat         Worldwide  ...
#
#       returnsAccepted conditionId listingIsTopRated  sellerFeedbackScore  \
# 0                  -1        1000                 0                 1473
# 2                  -1        1500                 0                 1465
# 3                  -1        3000                 0                 1466
# 6                  -1        3000                 0                  232
# 7                  -1        1000                 0                 1509
# ...               ...         ...               ...                  ...
# 2807               -1          -1                 1                24893
# 2808               -1        3000                 0                   61
# 2847               -1        3000                 0                 1466
# 2871               -1        7000                 0                  531
# 2886               -1        7000                 0                 8528
#
#       sellerPositivePercent           sellerName  sellerIsTopRated      price  \
# 0                     100.0               bik038                 0      £8.50
# 2                     100.0             dantsr99                 0      £2.39
# 3                     100.0          lizzie-drip                 0     £10.00
# 6                     100.0             khun6253                 0      £3.20
# 7                     100.0        divingace1968                 0      £3.00
# ...                     ...                  ...               ...        ...
# 2807                  100.0              upayles                 1     £25.00
# 2808                   95.0          gdarling777                 0      £6.99
# 2847                  100.0          hazelkinsey                 0      £1.60
# 2871                  100.0  eastcoasteclecticuk                 0     £42.58
# 2886                   98.9         alextrader16                 0  EUR 47.50
#
#      currency  bids
# 0          -1    12
# 2          -1     2
# 3          -1     1
# 6          -1     5
# 7          -1     2
# ...       ...   ...
# 2807       -1     1
# 2808       -1     1
# 2847       -1     5
# 2871       -1     3
# 2886       -1    12
#
# [442 rows x 23 columns]

# %%
df_books
# Out:
#       index            id                                              title  \
# 0         1  155231441853                   Harry Potter House Edition Books
# 1         2  374332149207  harry potter book set 1-7. Hardbacks and paper...
# 2         4  204134034335  Harry Potter and the Philosopher's Stone VINTA...
# 3         6  374332118703                             Harry Potter books 1-7
# 4         7  225230024645                 Harry Potter Complete Book Set 1-7
# ...     ...           ...                                                ...
# 1291   2707  225239799887  SIGNED HARRY POTTER BOOK PAGE JOB LOT CHARITY ...
# 1297   2717  374340331109  Harry Potter and the Philosopher's Stone: Comp...
# 1298   2718  225239787931  Job Lot Bundle Of Harry Potter Audio Book Cass...
# 1303   2723  155242851862  LEGO MINI FIGURE/FUN TIME BOOK. HARRY POTTER. ...
# 1311   2731  204144520896  Harry Potter and the Order of the Phoenix Audi...
#
#      globalId  categoryId          categoryName  \
# 0     EBAY-GB      261186                 Books
# 1     EBAY-GB      261186                 Books
# 2     EBAY-GB      261186                 Books
# 3     EBAY-GB      261186                 Books
# 4     EBAY-GB      261186                 Books
# ...       ...         ...                   ...
# 1291  EBAY-GB       69530                  Film
# 1297  EBAY-GB       29792           Audio Books
# 1298  EBAY-GB       29792           Audio Books
# 1303  EBAY-GB      263012  LEGO (R) Minifigures
# 1311  EBAY-GB       29792           Audio Books
#
#                                                     url  \
# 0     https://www.ebay.co.uk/itm/Harry-Potter-House-...
# 1     https://www.ebay.co.uk/itm/harry-potter-book-s...
# 2     https://www.ebay.co.uk/itm/Harry-Potter-and-Ph...
# 3     https://www.ebay.co.uk/itm/Harry-Potter-books-...
# 4     https://www.ebay.co.uk/itm/Harry-Potter-Comple...
# ...                                                 ...
# 1291  https://www.ebay.co.uk/itm/SIGNED-HARRY-POTTER...
# 1297  https://www.ebay.co.uk/itm/Harry-Potter-and-Ph...
# 1298  https://www.ebay.co.uk/itm/Job-Lot-Bundle-Harr...
# 1303  https://www.ebay.co.uk/itm/LEGO-MINI-FIGURE-FU...
# 1311  https://www.ebay.co.uk/itm/Harry-Potter-and-Or...
#
#                         location shippingType shippingLocations  ...  \
# 0        Bridgend,United Kingdom         Flat         Worldwide  ...
# 1         Walsall,United Kingdom         Flat         Worldwide  ...
# 2     Southampton,United Kingdom         Flat         Worldwide  ...
# 3         Walsall,United Kingdom         Flat         Worldwide  ...
# 4       Sheffield,United Kingdom         Flat         Worldwide  ...
# ...                          ...          ...               ...  ...
# 1291      Glasgow,United Kingdom         Flat         Worldwide  ...
# 1297         Bath,United Kingdom         Flat         Worldwide  ...
# 1298      Ipswich,United Kingdom         Flat         Worldwide  ...
# 1303   Canterbury,United Kingdom         Flat         Worldwide  ...
# 1311    Fleetwood,United Kingdom         Flat         Worldwide  ...
#
#       returnsAccepted conditionId listingIsTopRated  sellerFeedbackScore  \
# 0                  -1        1000                 0                    4
# 1                  -1        5000                 0                  427
# 2                  -1        5000                 0                 8880
# 3                  -1        2750                 0                  427
# 4                  -1        5000                 1                 1574
# ...               ...         ...               ...                  ...
# 1291               -1          -1                 0                  749
# 1297               -1        4000                 0                   17
# 1298               -1        4000                 0                  328
# 1303               -1        1000                 0                  951
# 1311               -1        4000                 0                  247
#
#       sellerPositivePercent                    sellerName  sellerIsTopRated  \
# 0                     100.0                    jepro_2233                 0
# 1                     100.0                    gacar_7978                 0
# 2                     100.0  southamptonscificollectables                 0
# 3                     100.0                    gacar_7978                 0
# 4                     100.0                     fattyowls                 1
# ...                     ...                           ...               ...
# 1291                  100.0                   honeybun960                 0
# 1297                  100.0                   shma-783142                 0
# 1298                  100.0               aclightningbuys                 0
# 1303                   99.6                tigerblood1975                 0
# 1311                   99.0                   laurgrun_27                 0
#
#        price currency  bids
# 0     £80.00       -1     6
# 1      £8.50       -1     4
# 2     £10.02       -1    10
# 3     £46.00       -1    32
# 4     £12.50       -1    10
# ...      ...      ...   ...
# 1291  £49.99       -1     1
# 1297   £5.00       -1     1
# 1298   £4.00       -1     1
# 1303   £4.95       -1     1
# 1311  £15.99       -1     2
#
# [177 rows x 23 columns]

# %%
#clock sellerPositivePercent visualization
clock_x = df_clocks['sellerPositivePercent'].unique()
clock_y = df_clocks['sellerPositivePercent'].value_counts().tolist()

plt.title('Clock Seller Positive Percent Scatter Plot')

plt.scatter(clock_x, clock_y)
plt.show()

# %%
#book sellerPositivePercent visualization
book_x = df_books['sellerPositivePercent'].unique()
book_y = df_books['sellerPositivePercent'].value_counts().tolist()

plt.title('Book Seller Positive Percent Scatter Plot')

plt.scatter(book_x, book_y)
plt.show()

# %%
#clock price visualization
price_clock = df_clocks['price'].to_list()
for i in range(len(price_clock)):
    price_clock[i] = re.findall("\d+\.\d+", price_clock[i])

price_clock_list = []
for j in range(len(price_clock)):
    price_clock_list.append(float(price_clock[j][0]))

plt.title('Clock Price Boxplot')
plt.xlabel('Clock')
plt.ylabel('Price')

plt.boxplot(price_clock_list, showfliers=False)
plt.show()

# %%
#book price visualization
price_book = df_books['price'].to_list()
for i in range(len(price_book)):
    price_book[i] = re.findall("\d+\.\d+", price_book[i])

price_book_list = []
for j in range(len(price_book)):
    price_book_list.append(float(price_book[j][0]))

plt.boxplot(price_book_list,showfliers=False)

plt.title('Book Price Boxplot')
plt.xlabel('Book')
plt.ylabel('Price')

plt.show()

# %%
#clock bids visualization
df_clocks = df_clocks.loc[df_clocks['bids'] != 0]

plt.hist(df_clocks['bids'])

plt.title('Clock Bids Histogram')
plt.xlabel('Number of bids')
plt.ylabel('Frequency')

plt.show()

# %%
#book bids visualization
df_books = df_books.loc[df_books['bids'] != 0]

plt.hist(df_books['bids'])

plt.title('Book Bids Histogram')
plt.xlabel('Number of bids')
plt.ylabel('Frequency')

plt.show()
